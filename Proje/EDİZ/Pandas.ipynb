# %%
import pandas as pd

# %% [markdown]
# ### Veri tipleri
# #### Tek boyutlu veriler için seri

# %%
meyve = pd.Series(["Elma","Armut","Muz"])
meyve
# Out:
# 0     Elma
# 1    Armut
# 2      Muz
# dtype: object

# %%
renkler = pd.Series(["Kırmızı","Yeşil","Sarı"])
renkler
# Out:
# 0    Kırmızı
# 1      Yeşil
# 2       Sarı
# dtype: object

# %% [markdown]
# #### iki boyutlu veriler için dataframe

# %%
meyve_data = pd.DataFrame({"Meyve isim":meyve,"Renk":renkler})
meyve_data
# Out:
#   Meyve isim     Renk
# 0       Elma  Kırmızı
# 1      Armut    Yeşil
# 2        Muz     Sarı

# %%
Sayi = pd.Series([5,3,2])
Sayi
# Out:
# 0    5
# 1    3
# 2    2
# dtype: int64

# %%
meyve_data = pd.DataFrame({"Meyve isim":meyve,"Renk":renkler,"Sayı":Sayi})
meyve_data
# Out:
#   Meyve isim     Renk  Sayı
# 0       Elma  Kırmızı     5
# 1      Armut    Yeşil     3
# 2        Muz     Sarı     2

# %%
parca_isim = pd.Series(["Jant","Trigger Kayışı","Ayna Ayarlama Joystick"])
parca_marka = pd.Series(["Bosch","Atiker","Çelikler"])
adet = pd.Series([4,3,10])
parca_data = pd.DataFrame({"Parça İsmi":parca_isim,"Parça Marka":parca_marka,"Adet":adet})
parca_data
# Out:
#                Parça İsmi Parça Marka  Adet
# 0                    Jant       Bosch     4
# 1          Trigger Kayışı      Atiker     3
# 2  Ayna Ayarlama Joystick    Çelikler    10

# %%
cor_veri = pd.read_csv("covid-19-all.csv")
# ilk 10 satır # boş kalırsa 5 demektir
cor_veri.head(10)
# son 10 satır # boş kalırsa 5 demektir
cor_veri.tail(10)
# Out:
#        Country/Region                Province/State   Latitude   Longitude  \
# 111097         Zambia                           NaN -13.133897   27.849332
# 111098       Zimbabwe                           NaN -19.015438   29.154857
# 111099      Australia  Australian Capital Territory -35.473500  149.012400
# 111100      Australia               New South Wales -33.868800  151.209300
# 111101      Australia            Northern Territory -12.463400  130.845600
# 111102      Australia                    Queensland -27.469800  153.025100
# 111103      Australia               South Australia -34.928500  138.600700
# 111104      Australia                      Tasmania -42.882100  147.327200
# 111105      Australia                      Victoria -37.813600  144.963100
# 111106      Australia             Western Australia -31.950500  115.860500
#
#         Confirmed  Recovered  Deaths        Date
# 111097       84.0       37.0     3.0  2020-04-24
# ...

# %% [markdown]
# veriyi gözden geçirme

# %%
cor_veri.dtypes
# Out:
# Country/Region     object
# Province/State     object
# Latitude          float64
# Longitude         float64
# Confirmed         float64
# Recovered         float64
# Deaths            float64
# Date               object
# dtype: object

# %%
bizimveri = pd.read_csv("ankara_cankaya_26_4_2020.csv",delimiter=";",header=None)
bizimveri.columns = ["M2","Oda","Fiyat","Tarih","Yer"]
bizimveri
# Out:
#        M2  Oda         Fiyat           Tarih                              Yer
# 0   250.0  5+1  1.500.000 TL  25 Nisan  2020           \KavaklıdereÇankayaMh.
# 1   150.0  2+1    380.000 TL  25 Nisan  2020                \YıldızBirlikMah.
# 2   400.0  6+1    950.000 TL  25 Nisan  2020  \Gaziosmanpaşa(Gop)BüyükesatMh.
# 3   100.0  2+1    500.000 TL  24 Nisan  2020                \DikmenİlkadımMh.
# 4    90.0  1+1    735.000 TL  24 Nisan  2020  \Gaziosmanpaşa(Gop)BüyükesatMh.
# ..    ...  ...           ...             ...                              ...
# 95  130.0  3+1    495.000 TL  16 Nisan  2020               \AyrancıAyrancıMh.
# 96  232.0  5+1    750.000 TL  15 Nisan  2020     \KırkkonaklarKırkkonaklarMh.
# 97   75.0  1+1    399.000 TL  15 Nisan  2020               \YıldızİlkbaharMh.
# 98  125.0  3+1    368.000 TL  15 Nisan  2020               \DikmenHarbiyeMah.
# 99  165.0  3+1    350.000 TL  14 Nisan  2020                  \ÖveçlerAtaMah.
#
# [100 rows x 5 columns]

# %%
bizimveri.dtypes
# Out:
# M2       float64
# Oda       object
# Fiyat     object
# Tarih     object
# Yer       object
# dtype: object

# %%
cor_veri.index
# Out:
# RangeIndex(start=0, stop=111107, step=1)

# %%
cor_veri.describe()
cor_veri.info()
cor_veri.mean()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111107 entries, 0 to 111106
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country/Region  111107 non-null  object
#  1   Province/State  101830 non-null  object
#  2   Latitude        111106 non-null  float64
#  3   Longitude       111106 non-null  float64
#  4   Confirmed       111088 non-null  float64
#  5   Recovered       110719 non-null  float64
#  6   Deaths          110666 non-null  float64
#  7   Date            111107 non-null  object
# dtypes: float64(5), object(3)
# memory usage: 6.8+ MB
# Latitude      36.120991
# Longitude    -73.762799
# Confirmed    499.924375
# Recovered    126.554674
# Deaths        29.923942
# dtype: float64

# %%
cor_veri.sum()
# Out:
# Country/Region    ChinaChinaChinaChinaChinaChinaChinaChinaChinaC...
# Latitude                                                4.01326e+06
# Longitude                                              -8.19549e+06
# Confirmed                                               5.55356e+07
# Recovered                                                1.4012e+07
# Deaths                                                  3.31156e+06
# Date              2020-01-222020-01-222020-01-222020-01-222020-0...
# dtype: object

# %%
cor_veri.head()
# Out:
#   Country/Region Province/State  Latitude  Longitude  Confirmed  Recovered  \
# 0          China          Anhui   31.8257   117.2264        1.0        NaN
# 1          China        Beijing   40.1824   116.4142       14.0        NaN
# 2          China      Chongqing   30.0572   107.8740        6.0        NaN
# 3          China         Fujian   26.0789   117.9874        1.0        NaN
# 4          China          Gansu   37.8099   101.0583        NaN        NaN
#
#    Deaths        Date
# 0     NaN  2020-01-22
# 1     NaN  2020-01-22
# 2     NaN  2020-01-22
# 3     NaN  2020-01-22
# 4     NaN  2020-01-22

# %%
cor_veri.loc[2] # indise(pandasın indisi)  bakar
# Out:
# Country/Region         China
# Province/State     Chongqing
# Latitude             30.0572
# Longitude            107.874
# Confirmed                  6
# Recovered                NaN
# Deaths                   NaN
# Date              2020-01-22
# Name: 2, dtype: object

# %%
cor_veri.iloc[2]   # pozisyona bakar
# Out:
# Country/Region         China
# Province/State     Chongqing
# Latitude             30.0572
# Longitude            107.874
# Confirmed                  6
# Recovered                NaN
# Deaths                   NaN
# Date              2020-01-22
# Name: 2, dtype: object

# %%
cor_veri.iloc[:5,:2]
# Out:
#   Country/Region Province/State
# 0          China          Anhui
# 1          China        Beijing
# 2          China      Chongqing
# 3          China         Fujian
# 4          China          Gansu

# %%
yurt_veri =  cor_veri[cor_veri["Country/Region"]=="Turkey"]
pd.crosstab(yurt_veri["Confirmed"],yurt_veri["Recovered"])
# Out:
# Recovered  0.0      26.0     42.0     70.0     105.0    162.0    243.0    \
# Confirmed
# 1.0              2        0        0        0        0        0        0
# 5.0              2        0        0        0        0        0        0
# 6.0              1        0        0        0        0        0        0
# 18.0             1        0        0        0        0        0        0
# 47.0             1        0        0        0        0        0        0
# 98.0             1        0        0        0        0        0        0
# 192.0            1        0        0        0        0        0        0
# 359.0            1        0        0        0        0        0        0
# 670.0            1        0        0        0        0        0        0
# 1236.0           1        0        0        0        0        0        0
# 1529.0           1        0        0        0        0        0        0
# 1872.0           1        0        0        0        0        0        0
# ...

# %%
yurt_veri["Deaths"].plot();

# %%
yurt_veri
# Out:
#        Country/Region Province/State  Latitude  Longitude  Confirmed  \
# 4915           Turkey            NaN   38.9637    35.2433        1.0
# 5135           Turkey            NaN   38.9637    35.2433        1.0
# 5233           Turkey            NaN   38.9637    35.2433        5.0
# 5562           Turkey            NaN   38.9637    35.2433        5.0
# 5811           Turkey            NaN   38.9637    35.2433        6.0
# 6045           Turkey            NaN   38.9637    35.2433       18.0
# 6290           Turkey            NaN   38.9637    35.2433       47.0
# 6532           Turkey            NaN   38.9637    35.2433       98.0
# 6802           Turkey            NaN   38.9637    35.2433      192.0
# 7073           Turkey            NaN   38.9637    35.2433      359.0
# 7351           Turkey            NaN   38.9637    35.2433      670.0
# 10867          Turkey            NaN   38.9637    35.2433     1236.0
# 14436          Turkey            NaN   38.9637    35.2433     1529.0
# ...

# %%
yurt_veri.plot(y="Date",x="Deaths");
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-91899b3d26ee> in <module>
# ----> 1 yurt_veri.plot(y="Date",x="Deaths");
#
# C:\Anaconda3\envs\Python19\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# C:\Anaconda3\envs\Python19\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# C:\Anaconda3\envs\Python19\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
# ...

# %%
duzelt_yurt_veri = yurt_veri.copy()
duzelt_yurt_veri["Date"] = pd.to_datetime(yurt_veri["Date"],format="%d/%m/%Y")
duzelt_yurt_veri
# Out:
#        Country/Region Province/State  Latitude  Longitude  Confirmed  \
# 4915           Turkey            NaN   38.9637    35.2433        1.0
# 5135           Turkey            NaN   38.9637    35.2433        1.0
# 5233           Turkey            NaN   38.9637    35.2433        5.0
# 5562           Turkey            NaN   38.9637    35.2433        5.0
# 5811           Turkey            NaN   38.9637    35.2433        6.0
# 6045           Turkey            NaN   38.9637    35.2433       18.0
# 6290           Turkey            NaN   38.9637    35.2433       47.0
# 6532           Turkey            NaN   38.9637    35.2433       98.0
# 6802           Turkey            NaN   38.9637    35.2433      192.0
# 7073           Turkey            NaN   38.9637    35.2433      359.0
# 7351           Turkey            NaN   38.9637    35.2433      670.0
# 10867          Turkey            NaN   38.9637    35.2433     1236.0
# 14436          Turkey            NaN   38.9637    35.2433     1529.0
# ...

# %%
duzelt_yurt_veri.plot(y="Confirmed",x="Date");

# %%
cor_veri["Confirmed"].fillna(cor_veri["Confirmed"].mean(),inplace=True)
yurt_veri.reset_index(inplace=True)
import random as rnd
seri1 = pd.Series([rnd.randint(10,100) for i in range(46)])
yurt_veri["Yeni"] = seri1
yurt_veri
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-91bb4658192f> in <module>
#       1 cor_veri["Confirmed"].fillna(cor_veri["Confirmed"].mean(),inplace=True)
# ----> 2 yurt_veri.reset_index(inplace=True)
#       3 import random as rnd
#       4 seri1 = pd.Series([rnd.randint(10,100) for i in range(46)])
#       5 yurt_veri["Yeni"] = seri1
#
# C:\Anaconda3\envs\Python19\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4602                 # to ndarray and maybe infer different dtype
#    4603                 level_values = _maybe_casted_values(lev, lab)
# -> 4604                 new_obj.insert(0, name, level_values)
#    4605
#    4606         new_obj.index = new_index
#
# C:\Anaconda3\envs\Python19\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
# ...

# %%
yurt_veri["iyi mi"] = True
yurt_veri = yurt_veri.drop("level_0",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-123-103937fdff13> in <module>
#       1 yurt_veri["iyi mi"] = True
# ----> 2 yurt_veri = yurt_veri.drop("level_0",axis=1)
#
# C:\Anaconda3\envs\Python19\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# C:\Anaconda3\envs\Python19\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
yurt_veri = yurt_veri.drop("index",axis=1)
yurt_veri = yurt_veri.drop("iyi mi",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-126-d80c0e0bbaa3> in <module>
# ----> 1 yurt_veri = yurt_veri.drop("index",axis=1)
#       2 yurt_veri = yurt_veri.drop("iyi mi",axis=1)
#
# C:\Anaconda3\envs\Python19\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# C:\Anaconda3\envs\Python19\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
test_veri = yurt_veri.sample(frac=0.1)
test_veri.reset_index(drop=True,inplace=True)

# %%
test_veri["Yeni"] = test_veri["Yeni"].apply(lambda x: x%2==0)
test_veri
# Out:
#   Country/Region  Latitude  Longitude  Confirmed  Recovered  Deaths  \
# 0         Turkey   38.9637    35.2433      359.0        0.0     4.0
# 1         Turkey   38.9637    35.2433      670.0        0.0     9.0
# 2         Turkey   38.9637    35.2433    38226.0     1846.0   812.0
# 3         Turkey   38.9637    35.2433    27069.0     1042.0   574.0
#
#         Date   Yeni
# 0 2020-03-20   True
# 1 2020-03-21  False
# 2 2020-04-08   True
# 3 2020-04-05   True
